# %%
class BankAccount:
    def __init__(self, account_number, account_holder_name, balance=0):
        self.account_number = account_number
        self.account_holder_name = account_holder_name
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited {amount} dollars. Current balance is {self.balance} dollars.")
        else:
            print("Invalid amount. Deposit amount must be greater than 0.")

    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew {amount} dollars. Current balance is {self.balance} dollars.")
        else:
            print("Insufficient funds or invalid amount.")

# Example usage:
account1 = BankAccount("123456", "John Doe")
print(f"Account holder: {account1.account_holder_name}, Account number: {account1.account_number}, Balance: {account1.balance}")
account1.deposit(100)
account1.withdraw(50)
account1.withdraw(80)
# Out:
# Account holder: John Doe, Account number: 123456, Balance: 0
# Deposited 100 dollars. Current balance is 100 dollars.
# Withdrew 50 dollars. Current balance is 50 dollars.
# Insufficient funds or invalid amount.

# %%
class Employee:
    def __init__(self, employee_id, name, salary):
        self.employee_id = employee_id
        self.name = name
        self.salary = salary

    def calculate_yearly_bonus(self, bonus_percentage):
        bonus = (bonus_percentage / 100) * self.salary
        return bonus

    def display_details(self):
        print(f"Employee ID: {self.employee_id}")
        print(f"Name: {self.name}")
        print(f"Salary: ${self.salary}")
        
# Example usage:
employee1 = Employee("E123", "Alice", 50000)
employee1.display_details()
bonus_percentage = 10  # Assume a bonus percentage of 10%
bonus = employee1.calculate_yearly_bonus(bonus_percentage)
print(f"Yearly bonus: ${bonus}")
# Out:
# Employee ID: E123
# Name: Alice
# Salary: $50000
# Yearly bonus: $5000.0

# %%
class Vehicle:
    def __init__(self, vehicle_id, model, is_available=True):
        self.vehicle_id = vehicle_id
        self.model = model
        self.is_available = is_available

class VehicleRentalSystem:
    def __init__(self):
        self.vehicles = []

    def add_vehicle(self, vehicle):
        self.vehicles.append(vehicle)

    def rent_vehicle(self, vehicle_id):
        for vehicle in self.vehicles:
            if vehicle.vehicle_id == vehicle_id:
                if vehicle.is_available:
                    vehicle.is_available = False
                    print(f"Vehicle {vehicle_id} rented successfully.")
                else:
                    print(f"Vehicle {vehicle_id} is not available for rent.")
                return
        print(f"Vehicle {vehicle_id} not found.")

    def return_vehicle(self, vehicle_id):
        for vehicle in self.vehicles:
            if vehicle.vehicle_id == vehicle_id:
                vehicle.is_available = True
                print(f"Vehicle {vehicle_id} returned successfully.")
                return
        print(f"Vehicle {vehicle_id} not found.")

    def display_available_vehicles(self):
        print("Available Vehicles:")
        for vehicle in self.vehicles:
            if vehicle.is_available:
                print(f"ID: {vehicle.vehicle_id}, Model: {vehicle.model}")

# Example usage:
rental_system = VehicleRentalSystem()
vehicle1 = Vehicle("V001", "Toyota Camry")
vehicle2 = Vehicle("V002", "Honda Civic")
vehicle3 = Vehicle("V003", "Ford Mustang")
rental_system.add_vehicle(vehicle1)
rental_system.add_vehicle(vehicle2)
rental_system.add_vehicle(vehicle3)

rental_system.display_available_vehicles()

rental_system.rent_vehicle("V001")
rental_system.display_available_vehicles()

rental_system.return_vehicle("V001")
rental_system.display_available_vehicles()
# Out:
# Available Vehicles:
# ID: V001, Model: Toyota Camry
# ID: V002, Model: Honda Civic
# ID: V003, Model: Ford Mustang
# Vehicle V001 rented successfully.
# Available Vehicles:
# ID: V002, Model: Honda Civic
# ID: V003, Model: Ford Mustang
# Vehicle V001 returned successfully.
# Available Vehicles:
# ID: V001, Model: Toyota Camry
# ID: V002, Model: Honda Civic
# ID: V003, Model: Ford Mustang

# %%
class Book:
    def __init__(self, book_id, title, author):
        self.book_id = book_id
        self.title = title
        self.author = author
        self.is_available = True

class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)

    def borrow_book(self, book_id):
        for book in self.books:
            if book.book_id == book_id:
                if book.is_available:
                    book.is_available = False
                    print(f"Book '{book.title}' by {book.author} is borrowed successfully.")
                else:
                    print(f"Book '{book.title}' by {book.author} is not available for borrowing.")
                return
        print("Book not found.")

    def return_book(self, book_id):
        for book in self.books:
            if book.book_id == book_id:
                book.is_available = True
                print(f"Book '{book.title}' by {book.author} is returned successfully.")
                return
        print("Book not found.")

    def display_available_books(self):
        print("Available Books:")
        for book in self.books:
            if book.is_available:
                print(f"ID: {book.book_id}, Title: '{book.title}', Author: {book.author}")

# Example usage:
library = Library()
book1 = Book("B001", "To Kill a Mockingbird", "Harper Lee")
book2 = Book("B002", "1984", "George Orwell")
book3 = Book("B003", "Pride and Prejudice", "Jane Austen")

library.add_book(book1)
library.add_book(book2)
library.add_book(book3)

library.display_available_books()

library.borrow_book("B001")
library.borrow_book("B002")
library.display_available_books()

library.return_book("B001")
library.display_available_books()
# Out:
# Available Books:
# ID: B001, Title: 'To Kill a Mockingbird', Author: Harper Lee
# ID: B002, Title: '1984', Author: George Orwell
# ID: B003, Title: 'Pride and Prejudice', Author: Jane Austen
# Book 'To Kill a Mockingbird' by Harper Lee is borrowed successfully.
# Book '1984' by George Orwell is borrowed successfully.
# Available Books:
# ID: B003, Title: 'Pride and Prejudice', Author: Jane Austen
# Book 'To Kill a Mockingbird' by Harper Lee is returned successfully.
# Available Books:
# ID: B001, Title: 'To Kill a Mockingbird', Author: Harper Lee
# ID: B003, Title: 'Pride and Prejudice', Author: Jane Austen

# %%
class Product:
    def __init__(self, product_id, name, price, quantity):
        self.product_id = product_id
        self.name = name
        self.price = price
        self.quantity = quantity

class Inventory:
    def __init__(self):
        self.products = []

    def add_product(self, product):
        self.products.append(product)

    def update_quantity(self, product_id, new_quantity):
        for product in self.products:
            if product.product_id == product_id:
                product.quantity = new_quantity
                print(f"Quantity updated for product {product_id}. New quantity: {new_quantity}")
                return
        print("Product not found.")

    def display_available_products(self):
        print("Available Products:")
        for product in self.products:
            print(f"ID: {product.product_id}, Name: {product.name}, Price: ${product.price}, Quantity: {product.quantity}")

# Example usage:
inventory = Inventory()
product1 = Product("P001", "Laptop", 999.99, 10)
product2 = Product("P002", "Smartphone", 599.99, 20)
product3 = Product("P003", "Tablet", 299.99, 15)

inventory.add_product(product1)
inventory.add_product(product2)
inventory.add_product(product3)

inventory.display_available_products()

inventory.update_quantity("P001", 5)
inventory.display_available_products()
# Out:
# Available Products:
# ID: P001, Name: Laptop, Price: $999.99, Quantity: 10
# ID: P002, Name: Smartphone, Price: $599.99, Quantity: 20
# ID: P003, Name: Tablet, Price: $299.99, Quantity: 15
# Quantity updated for product P001. New quantity: 5
# Available Products:
# ID: P001, Name: Laptop, Price: $999.99, Quantity: 5
# ID: P002, Name: Smartphone, Price: $599.99, Quantity: 20
# ID: P003, Name: Tablet, Price: $299.99, Quantity: 15

# %%
class Shape:
    def __init__(self, length, width=None, height=None):
        self.length = length
        self.width = width
        self.height = height

    def calculate_area(self):
        raise NotImplementedError("Subclass must implement abstract method")

    def calculate_perimeter(self):
        raise NotImplementedError("Subclass must implement abstract method")

class Rectangle(Shape):
    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)

class Square(Rectangle):
    def __init__(self, side):
        super().__init__(side, side)

# Example usage:
rectangle = Rectangle(5, 3)
print("Rectangle:")
print("Area:", rectangle.calculate_area())
print("Perimeter:", rectangle.calculate_perimeter())

square = Square(4)
print("\nSquare:")
print("Area:", square.calculate_area())
print("Perimeter:", square.calculate_perimeter())
# Out:
# Rectangle:
# Area: 15
# Perimeter: 16
#
# Square:
# Area: 16
# Perimeter: 16

# %%
class Student:
    def __init__(self, student_id, name):
        self.student_id = student_id
        self.name = name
        self.grades = []

    def add_grade(self, grade):
        self.grades.append(grade)

    def calculate_average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)

    def display_details(self):
        print(f"Student ID: {self.student_id}")
        print(f"Name: {self.name}")
        print("Grades:", ", ".join(map(str, self.grades)))
        print(f"Average Grade: {self.calculate_average_grade()}")

# Example usage:
student1 = Student("S001", "Alice")
student1.add_grade(85)
student1.add_grade(90)
student1.add_grade(78)

student1.display_details()
# Out:
# Student ID: S001
# Name: Alice
# Grades: 85, 90, 78
# Average Grade: 84.33333333333333

# %%
class Email:
    def __init__(self, sender, recipient, subject, body):
        self.sender = sender
        self.recipient = recipient
        self.subject = subject
        self.body = body

    def send_email(self):
        print(f"Email sent from: {self.sender}")
        print(f"Email sent to: {self.recipient}")
        print(f"Subject: {self.subject}")
        print("Body:")
        print(self.body)
        print("Email sent successfully.")

    def display_details(self):
        print("Email Details:")
        print(f"Sender: {self.sender}")
        print(f"Recipient: {self.recipient}")
        print(f"Subject: {self.subject}")
        print("Body:")
        print(self.body)

# Example usage:
email = Email("john@example.com", "jane@example.com", "Meeting Agenda", "Dear Jane, \n\nPlease find attached the agenda for our upcoming meeting. \n\nBest regards, \nJohn")
email.send_email()

print("\n")

email.display_details()
# Out:
# Email sent from: john@example.com
# Email sent to: jane@example.com
# Subject: Meeting Agenda
# Body:
# Dear Jane,
#
# Please find attached the agenda for our upcoming meeting.
#
# Best regards,
# John
# Email sent successfully.
#
#
# Email Details:
# Sender: john@example.com
# Recipient: jane@example.com
# Subject: Meeting Agenda
# Body:
# Dear Jane,
#
# Please find attached the agenda for our upcoming meeting.
#
# Best regards,
# John

# %%
class SocialMediaProfile:
    def __init__(self, username):
        self.username = username
        self.posts = []

    def add_post(self, post):
        self.posts.append(post)

    def display_posts(self):
        if self.posts:
            print(f"Posts by {self.username}:")
            for index, post in enumerate(self.posts, start=1):
                print(f"Post {index}: {post}")
        else:
            print("No posts available.")

    def search_posts_by_keyword(self, keyword):
        matching_posts = [post for post in self.posts if keyword.lower() in post.lower()]
        if matching_posts:
            print(f"Posts containing '{keyword}':")
            for index, post in enumerate(matching_posts, start=1):
                print(f"Post {index}: {post}")
        else:
            print(f"No posts containing '{keyword}' found.")

# Example usage:
profile = SocialMediaProfile("JohnDoe")
profile.add_post("Hello world! This is my first post.")
profile.add_post("Just finished an amazing hike! 🌄 #naturelover")
profile.add_post("Excited to start my new job tomorrow!")

profile.display_posts()

print("\n")

profile.search_posts_by_keyword("nature")

print("\n")

profile.search_posts_by_keyword("job")
# Out:
# Posts by JohnDoe:
# Post 1: Hello world! This is my first post.
# Post 2: Just finished an amazing hike! 🌄 #naturelover
# Post 3: Excited to start my new job tomorrow!
#
#
# Posts containing 'nature':
# Post 1: Just finished an amazing hike! 🌄 #naturelover
#
#
# Posts containing 'job':
# Post 1: Excited to start my new job tomorrow!

# %%
class ToDoList:
    def __init__(self):
        self.tasks = []

    def add_task(self, task, due_date):
        self.tasks.append({"task": task, "due_date": due_date, "completed": False})

    def mark_task_as_completed(self, task_index):
        if 0 <= task_index < len(self.tasks):
            self.tasks[task_index]["completed"] = True
            print(f"Task '{self.tasks[task_index]['task']}' marked as completed.")
        else:
            print("Invalid task index.")

    def display_pending_tasks(self):
        pending_tasks = [task for task in self.tasks if not task["completed"]]
        if pending_tasks:
            print("Pending Tasks:")
            for index, task in enumerate(pending_tasks, start=1):
                print(f"{index}. Task: {task['task']}, Due Date: {task['due_date']}")
        else:
            print("No pending tasks.")

# Example usage:
todo_list = ToDoList()
todo_list.add_task("Complete assignment", "2024-02-29")
todo_list.add_task("Buy groceries", "2024-03-01")
todo_list.add_task("Call mom", "2024-03-02")

todo_list.display_pending_tasks()

print("\n")

todo_list.mark_task_as_completed(0)
todo_list.display_pending_tasks()
# Out:
# Pending Tasks:
# 1. Task: Complete assignment, Due Date: 2024-02-29
# 2. Task: Buy groceries, Due Date: 2024-03-01
# 3. Task: Call mom, Due Date: 2024-03-02
#
#
# Task 'Complete assignment' marked as completed.
# Pending Tasks:
# 1. Task: Buy groceries, Due Date: 2024-03-01
# 2. Task: Call mom, Due Date: 2024-03-02
